# %%
from pandas import read_csv
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
df = read_csv("bankdaten.csv", usecols=[1, 2, 3])
df
# Out:
#     Buchungstag  Betrag                    Kategorie
# 0    2019-06-28    3.00  Dienstleistungen & Gebühren
# 1    2019-06-28    8.15  Nahrung & Verbrauchsartikel
# 2    2019-06-28   11.73  Nahrung & Verbrauchsartikel
# 3    2019-06-28   31.65  Nahrung & Verbrauchsartikel
# 4    2019-06-27   11.44  Nahrung & Verbrauchsartikel
# ..          ...     ...                          ...
# 623  2018-06-07    5.00  Dienstleistungen & Gebühren
# 624  2018-06-06   72.48          Unbekannt & Bargeld
# 625  2018-06-05   44.89    Miete & laufende Verträge
# 626  2018-06-04   98.29                 Unterhaltung
# 627  2018-06-04   84.00    Miete & laufende Verträge
#
# [628 rows x 3 columns]

# %%
alt.Chart(df).mark_bar().encode(
    x=alt.X("yearmonth(Buchungstag):O", title="Monat"), 
    y=alt.Y("sum(Betrag)", title="Monatliche Ausgaben"), 
    color="Kategorie").properties(width=700, height=400)
